# %%
# !pip3.12 install --force-reinstall mediapipe
# Out:
# ...
#   Using cached mediapipe-0.10.14-cp312-cp312-macosx_11_0_universal2.whl.metadata (9.7 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached jax-0.4.30-py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached jaxlib-0.4.30-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.0 kB)
# ...
#   Using cached matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached numpy-2.0.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# ...
#   Using cached opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached protobuf-4.25.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# ...
#   Using cached sounddevice-0.4.7-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata (1.4 kB)
# ...
#   Using cached cffi-1.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# ...

# %%
import mediapipe as mp
import cv2

try:
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands()
    cap = cv2.VideoCapture(1)
    cv2.startWindowThread()

    # Initialize drawing utils
    mp_drawing = mp.solutions.drawing_utils
    while cap.isOpened():
        suc, img = cap.read()
        if(suc != True):
            print("camera not opening")
            continue
        cv2.imshow('OBJDETECT', img)
        img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        res = hands.process(img2)
        if res.multi_hand_landmarks:
            array = Pen.get_current_location(res)
            print(array)
        cv2.imshow('img', img)
        if cv2.waitKey(1) == ord('q'):
            print("INTERRUPT detected!!")
            break 

except Exception as e:
    cap.release()
    cv2.destroyAllWindows()
    for i in range(1, 5):
        cv2.waitKey(1)
else:
    cap.release()
    cv2.destroyAllWindows()
    for i in range(1, 5):
        cv2.waitKey(1)
# Out:
# I0000 00:00:1722048260.163877  228342 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M2
# W0000 00:00:1722048260.172954  229771 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1722048260.219932  229772 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Users/eric/Documents/FingerDraw/.venv/lib/python3.12/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
import mediapipe as mp
import numpy as np

mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Initialize drawing utils
mp_drawing = mp.solutions.drawing_utils

class Pen:
    def get_current_location(results) -> float:
        finger = []
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                finger.append(hand_landmarks.landmark[4].x, hand_landmarks.landmark[4].y)
        
        return finger
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722048146.896681  228342 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1722048146.919468  228509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1722048146.938448  228509 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
